# %%
import pandas as pd
df = pd.read_csv("C:/Users/PC/Downloads/STEG_BILLING_HISTORY.csv")
data
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_10484\4073292732.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/PC/Downloads/STEG_BILLING_HISTORY.csv")
#                   client_id invoice_date  tarif_type  counter_number  \
# 0            train_Client_0   2014-03-24          11       1335667.0
# 1            train_Client_0   2013-03-29          11       1335667.0
# 2            train_Client_0   2015-03-23          11       1335667.0
# 3            train_Client_0   2015-07-13          11       1335667.0
# 4            train_Client_0   2016-11-17          11       1335667.0
# ...                     ...          ...         ...             ...
# 4476744  train_Client_99998   2005-08-19          10       1253571.0
# 4476745  train_Client_99998   2005-12-19          10       1253571.0
# 4476746  train_Client_99999   1996-09-25          11        560948.0
# ...

# %%
client_0_bills = df.head(10)
print(client_0_bills)
# Out:
#         client_id invoice_date  tarif_type  counter_number counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0              0
# 1  train_Client_0   2013-03-29          11       1335667.0              0
# 2  train_Client_0   2015-03-23          11       1335667.0              0
# 3  train_Client_0   2015-07-13          11       1335667.0              0
# 4  train_Client_0   2016-11-17          11       1335667.0              0
# 5  train_Client_0   2017-07-17          11       1335667.0              0
# 6  train_Client_0   2018-12-07          11       1335667.0              0
# 7  train_Client_0   2019-03-19          11       1335667.0              0
# 8  train_Client_0   2011-07-22          11       1335667.0              0
# 9  train_Client_0   2011-11-22          11       1335667.0              0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
print(type(client_0_bills))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4476749 entries, 0 to 4476748
# Data columns (total 16 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   client_id             object
#  1   invoice_date          object
#  2   tarif_type            int64
#  3   counter_number        float64
#  4   counter_statue        object
#  5   counter_code          int64
#  6   reading_remarque      float64
#  7   counter_coefficient   int64
#  8   consommation_level_1  int64
#  9   consommation_level_2  int64
#  10  consommation_level_3  int64
#  11  consommation_level_4  int64
#  12  old_index             int64
#  13  new_index             int64
#  14  months_number         int64
#  15  counter_type          object
# dtypes: float64(2), int64(10), object(4)
# memory usage: 546.5+ MB
# None

# %%
print(f"Nombre de lignes : {df.shape[0]}")
print(f"Nombre de colonnes : {df.shape[1]}")
# Out:
# Nombre de lignes : 4476749
# Nombre de colonnes : 16

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns
print(f"Nombre de caractéristiques catégorielles : {len(categorical_columns)}")
# Out:
# Nombre de caractéristiques catégorielles : 4

# %%
print(df.memory_usage(deep=True).sum(), "bytes")
# Out:
# 1499843451 bytes

# %%
missing_values = df.isnull().sum()
print("Valeurs manquantes par colonne :")
print(missing_values)
# Out:
# Valeurs manquantes par colonne :
# client_id                  0
# invoice_date               0
# tarif_type                 0
# counter_number            48
# counter_statue             0
# counter_code               0
# reading_remarque        4531
# counter_coefficient        0
# consommation_level_1       0
# consommation_level_2       0
# consommation_level_3       0
# consommation_level_4       0
# old_index                  0
# new_index                  0
# months_number              0
# counter_type               0
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        df[col].fillna(df[col].median(), inplace=True)

# %%
numeric_columns = df.select_dtypes(include=[np.number]).columns
print(df[numeric_columns].describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 np = df.select_dtypes(include=[np.number]).columns
#       2 print(df[numeric_columns].describe())
#
# NameError: name 'np' is not defined

# %%
client_0_bills_method1 = df[df['client_id'] == 'train_Client_0']

# %%
client_0_bills_method2 = df.query("client_id == 'train_Client_0'")

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['counter_type'] = label_encoder.fit_transform(df['counter_type'])

# %%
df.drop(columns=['counter_statue'], inplace=True)

# %%
print(df.head())
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_code  \
# 0  train_Client_0   2014-03-24          11       1335667.0           203
# 1  train_Client_0   2013-03-29          11       1335667.0           203
# 2  train_Client_0   2015-03-23          11       1335667.0           203
# 3  train_Client_0   2015-07-13          11       1335667.0           207
# 4  train_Client_0   2016-11-17          11       1335667.0           207
#
#    reading_remarque  counter_coefficient  consommation_level_1  \
# 0               8.0                    1                    82
# 1               6.0                    1                  1200
# 2               8.0                    1                   123
# 3               8.0                    1                   102
# 4               9.0                    1                   572
#
#    consommation_level_2  consommation_level_3  consommation_level_4  \
# 0                     0                     0                     0
# ...
